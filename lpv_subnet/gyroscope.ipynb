# %%
import deepSI
import numpy as np
from scipy.io import loadmat
from encoder_LPV_models import LPV_multi_encoder, LPV_single_encoder
from matplotlib import pyplot as plt

# %%
out = loadmat('gyroscope_data/ML_estim.mat')
u = np.concatenate([out['u_i2'], out['u_q1d']], axis = 1)
y = out['y_q4d'][:, 0]
train = deepSI.System_data(u = u, y = y)
out = loadmat('gyroscope_data/ML_valid.mat')
u = np.concatenate([out['u_i2'], out['u_q1d']], axis = 1)
y = out['y_q4d'][:, 0]
test = deepSI.System_data(u = u, y = y)

# %%
train.plot()
plt.title("Training set")
plt.grid()
plt.show()

test.plot()
plt.title("Test set")
plt.grid()
plt.show()

# %%
sys = LPV_single_encoder(nx=5, Np=3, na=10, nb=10, feedthrough=True, include_u_in_p=True, f_net_kwargs=dict(F=10), \
                        e_net_kwargs=dict(n_nodes_per_layer = 64, n_hidden_layers = 2), \
                        p_net_kwargs=dict(n_nodes_per_layer = 64, n_hidden_layers = 2))
sys.init_model(sys_data=train)

# %%
sys.fit(train, train[-25000:], epochs = 1000, loss_kwargs=dict(nf=80, loss_nf_cutoff=1))
# Out:
# Model already initilized (init_model_done=True), skipping initilizing of the model, the norm and the creation of the optimizer
# Size of the training array =  20.4 MB
# N_training_samples = 9911, batch_size = 256, N_batch_updates_per_epoch = 38
# Initial Validation sim-NRMS= 0.729445735857911
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.7293657589314393
# Epoch    1, sqrt loss  0.6823, Val sim-NRMS 0.7294, Time Loss: 59.8%, data: 0.1%, val: 40.1%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.7285369010857011
# Epoch    2, sqrt loss  0.6813, Val sim-NRMS 0.7285, Time Loss: 59.8%, data: 0.1%, val: 40.1%,  1.5 batches/sec
# Epoch    3, sqrt loss  0.6788, Val sim-NRMS 0.7286, Time Loss: 59.9%, data: 0.1%, val: 40.1%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.7273569744636985
# Epoch    4, sqrt loss  0.6773, Val sim-NRMS 0.7274, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.7264316306410843
# Epoch    5, sqrt loss  0.6747, Val sim-NRMS 0.7264, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.7253560137380152
# Epoch    6, sqrt loss  0.6696, Val sim-NRMS 0.7254, Time Loss: 60.0%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.7094409034728035
# Epoch    7, sqrt loss   0.655, Val sim-NRMS 0.7094, Time Loss: 59.0%, data: 0.1%, val: 40.9%,  1.4 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.4989816084906415
# Epoch    8, sqrt loss  0.4395, Val sim-NRMS  0.499, Time Loss: 59.8%, data: 0.1%, val: 40.1%,  1.4 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.4154247931894471
# Epoch    9, sqrt loss  0.2205, Val sim-NRMS 0.4154, Time Loss: 59.8%, data: 0.1%, val: 40.2%,  1.4 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.38475392658788243
# Epoch   10, sqrt loss  0.1688, Val sim-NRMS 0.3848, Time Loss: 59.8%, data: 0.1%, val: 40.1%,  1.4 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.32108415562920894
# Epoch   11, sqrt loss  0.1282, Val sim-NRMS 0.3211, Time Loss: 59.8%, data: 0.1%, val: 40.1%,  1.4 batches/sec
# Epoch   12, sqrt loss  0.1274, Val sim-NRMS 0.3255, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.4 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.25283490700418354
# Epoch   13, sqrt loss  0.1161, Val sim-NRMS 0.2528, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.4 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.21192466167028245
# Epoch   14, sqrt loss  0.1018, Val sim-NRMS 0.2119, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.4 batches/sec
# Epoch   15, sqrt loss 0.08872, Val sim-NRMS 0.2257, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.4 batches/sec
# Epoch   16, sqrt loss  0.1399, Val sim-NRMS 0.5751, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.4 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.16775248688205163
# Epoch   17, sqrt loss 0.09056, Val sim-NRMS 0.1678, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.4 batches/sec
# Epoch   18, sqrt loss 0.07464, Val sim-NRMS 0.2437, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.4 batches/sec
# Epoch   19, sqrt loss 0.07146, Val sim-NRMS 0.1694, Time Loss: 59.9%, data: 0.1%, val: 40.1%,  1.4 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.15152388044221257
# Epoch   20, sqrt loss 0.06717, Val sim-NRMS 0.1515, Time Loss: 59.9%, data: 0.1%, val: 40.1%,  1.4 batches/sec
# Epoch   21, sqrt loss  0.0695, Val sim-NRMS 0.2967, Time Loss: 59.9%, data: 0.1%, val: 40.1%,  1.5 batches/sec
# Epoch   22, sqrt loss  0.0935, Val sim-NRMS  0.945, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.13862449230871932
# Epoch   23, sqrt loss  0.1164, Val sim-NRMS 0.1386, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# Epoch   24, sqrt loss 0.06349, Val sim-NRMS 0.1719, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.1222121478544562
# Epoch   25, sqrt loss 0.05859, Val sim-NRMS 0.1222, Time Loss: 59.9%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# Epoch   26, sqrt loss 0.05845, Val sim-NRMS 0.1733, Time Loss: 60.0%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.11177389216775031
# Epoch   27, sqrt loss 0.05468, Val sim-NRMS 0.1118, Time Loss: 60.0%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# Epoch   28, sqrt loss 0.05262, Val sim-NRMS 0.1532, Time Loss: 60.0%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# Epoch   29, sqrt loss 0.05114, Val sim-NRMS 0.1252, Time Loss: 60.0%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# Epoch   30, sqrt loss 0.06167, Val sim-NRMS 0.4407, Time Loss: 60.0%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# Epoch   31, sqrt loss  0.3734, Val sim-NRMS 0.3388, Time Loss: 60.0%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# Epoch   32, sqrt loss  0.1227, Val sim-NRMS 0.2092, Time Loss: 60.0%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# Epoch   33, sqrt loss 0.06481, Val sim-NRMS 0.1582, Time Loss: 60.0%, data: 0.1%, val: 40.0%,  1.5 batches/sec
# Epoch   34, sqrt loss 0.05556, Val sim-NRMS 0.1302, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   35, sqrt loss 0.05314, Val sim-NRMS  0.129, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   36, sqrt loss 0.04951, Val sim-NRMS 0.1244, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   37, sqrt loss 0.04756, Val sim-NRMS 0.1192, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   38, sqrt loss 0.04527, Val sim-NRMS 0.1451, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   39, sqrt loss 0.04421, Val sim-NRMS 0.1223, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   40, sqrt loss 0.04327, Val sim-NRMS 0.1349, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.10678379890098869
# Epoch   41, sqrt loss 0.04248, Val sim-NRMS 0.1068, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.1029598980377257
# Epoch   42, sqrt loss 0.04471, Val sim-NRMS  0.103, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.09719625516957181
# Epoch   43, sqrt loss 0.04125, Val sim-NRMS 0.0972, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   44, sqrt loss 0.04366, Val sim-NRMS 0.1378, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   45, sqrt loss 0.04032, Val sim-NRMS 0.1045, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   46, sqrt loss  0.1338, Val sim-NRMS 0.6857, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   47, sqrt loss   0.709, Val sim-NRMS 0.7372, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   48, sqrt loss  0.6725, Val sim-NRMS 0.7219, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   49, sqrt loss  0.4728, Val sim-NRMS 0.5216, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   50, sqrt loss  0.1194, Val sim-NRMS 0.1637, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   51, sqrt loss 0.05727, Val sim-NRMS  0.128, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   52, sqrt loss 0.04845, Val sim-NRMS 0.1299, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   53, sqrt loss 0.04283, Val sim-NRMS 0.1213, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   54, sqrt loss 0.04159, Val sim-NRMS 0.1383, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   55, sqrt loss  0.0414, Val sim-NRMS 0.1022, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   56, sqrt loss 0.03809, Val sim-NRMS 0.1255, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.0920762160023909
# Epoch   57, sqrt loss 0.03835, Val sim-NRMS 0.09208, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   58, sqrt loss  0.0356, Val sim-NRMS 0.09342, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   59, sqrt loss 0.03523, Val sim-NRMS 0.1303, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   60, sqrt loss 0.03677, Val sim-NRMS 0.1372, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   61, sqrt loss 0.03535, Val sim-NRMS 0.09257, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.08577630974459816
# Epoch   62, sqrt loss 0.03672, Val sim-NRMS 0.08578, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   63, sqrt loss 0.03646, Val sim-NRMS 0.1381, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   64, sqrt loss 0.03314, Val sim-NRMS 0.09654, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   65, sqrt loss 0.09432, Val sim-NRMS 0.2513, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   66, sqrt loss 0.05093, Val sim-NRMS 0.09838, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.0837296638896719
# Epoch   67, sqrt loss 0.03425, Val sim-NRMS 0.08373, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.08303518967228767
# Epoch   68, sqrt loss 0.03251, Val sim-NRMS 0.08304, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   69, sqrt loss 0.03266, Val sim-NRMS 0.1502, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   70, sqrt loss  0.1008, Val sim-NRMS 0.6405, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# 70 Epoch   71, sqrt loss  0.6444, Val sim-NRMS 0.6911, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   72, sqrt loss  0.3493, Val sim-NRMS 0.4185, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   73, sqrt loss  0.0852, Val sim-NRMS 0.1748, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   74, sqrt loss 0.05408, Val sim-NRMS  0.125, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   75, sqrt loss 0.04127, Val sim-NRMS 0.1116, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   76, sqrt loss 0.03775, Val sim-NRMS 0.1569, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   77, sqrt loss 0.03647, Val sim-NRMS 0.08668, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   78, sqrt loss 0.03261, Val sim-NRMS 0.1002, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.07968899482705796
# Epoch   79, sqrt loss 0.03289, Val sim-NRMS 0.07969, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.07587044031417386
# Epoch   80, sqrt loss 0.03074, Val sim-NRMS 0.07587, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   81, sqrt loss 0.03088, Val sim-NRMS  0.171, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.07132254442349092
# Epoch   82, sqrt loss 0.03119, Val sim-NRMS 0.07132, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   83, sqrt loss 0.03204, Val sim-NRMS 0.09636, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   84, sqrt loss 0.02973, Val sim-NRMS 0.09328, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   85, sqrt loss 0.02949, Val sim-NRMS 0.09407, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   86, sqrt loss 0.03031, Val sim-NRMS  0.082, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   87, sqrt loss 0.03007, Val sim-NRMS 0.0752, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.06463803029523175
# Epoch   88, sqrt loss 0.02737, Val sim-NRMS 0.06464, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   89, sqrt loss 0.02866, Val sim-NRMS 0.08734, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   90, sqrt loss 0.03634, Val sim-NRMS 0.4734, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   91, sqrt loss  0.6191, Val sim-NRMS 0.7513, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   92, sqrt loss  0.6897, Val sim-NRMS 0.7261, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   93, sqrt loss  0.5625, Val sim-NRMS 0.4175, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   94, sqrt loss  0.1355, Val sim-NRMS 0.2482, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   95, sqrt loss 0.05601, Val sim-NRMS 0.1308, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   96, sqrt loss 0.04211, Val sim-NRMS 0.09884, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   97, sqrt loss 0.03654, Val sim-NRMS 0.1286, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   98, sqrt loss 0.03473, Val sim-NRMS 0.07866, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch   99, sqrt loss  0.0348, Val sim-NRMS 0.1149, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  100, sqrt loss 0.03143, Val sim-NRMS 0.09314, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  101, sqrt loss 0.02915, Val sim-NRMS 0.09412, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.06059787628503894
# Epoch  102, sqrt loss 0.02935, Val sim-NRMS 0.0606, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  103, sqrt loss 0.02834, Val sim-NRMS 0.08256, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  104, sqrt loss 0.02852, Val sim-NRMS 0.07365, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  105, sqrt loss 0.04284, Val sim-NRMS  0.297, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  106, sqrt loss 0.09854, Val sim-NRMS 0.09976, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  107, sqrt loss 0.03853, Val sim-NRMS 0.1031, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.0591141144871835
# Epoch  108, sqrt loss 0.02779, Val sim-NRMS 0.05911, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  109, sqrt loss 0.02886, Val sim-NRMS 0.06347, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  110, sqrt loss  0.1625, Val sim-NRMS 0.3714, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  111, sqrt loss 0.09358, Val sim-NRMS 0.1952, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  112, sqrt loss 0.03972, Val sim-NRMS 0.0877, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  113, sqrt loss 0.02971, Val sim-NRMS 0.0772, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  114, sqrt loss 0.02855, Val sim-NRMS 0.0633, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  115, sqrt loss 0.02662, Val sim-NRMS 0.09479, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.057001165886339134
# Epoch  116, sqrt loss 0.02698, Val sim-NRMS  0.057, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  117, sqrt loss 0.02824, Val sim-NRMS 0.1605, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  118, sqrt loss 0.03001, Val sim-NRMS 0.1495, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  119, sqrt loss 0.02661, Val sim-NRMS 0.06705, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  120, sqrt loss 0.02675, Val sim-NRMS 0.08526, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  121, sqrt loss 0.03702, Val sim-NRMS 0.6419, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  122, sqrt loss  0.3667, Val sim-NRMS 0.6461, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  123, sqrt loss  0.1742, Val sim-NRMS 0.2279, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  124, sqrt loss 0.06472, Val sim-NRMS 0.1676, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  125, sqrt loss 0.04557, Val sim-NRMS 0.1368, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  126, sqrt loss 0.03527, Val sim-NRMS 0.08129, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  127, sqrt loss 0.03095, Val sim-NRMS 0.09032, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  128, sqrt loss 0.02873, Val sim-NRMS 0.08964, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  129, sqrt loss 0.02724, Val sim-NRMS 0.06694, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.05671060415680175
# Epoch  130, sqrt loss 0.02688, Val sim-NRMS 0.05671, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  131, sqrt loss 0.02538, Val sim-NRMS 0.06807, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  132, sqrt loss 0.02433, Val sim-NRMS 0.1034, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.0539590723051544
# Epoch  133, sqrt loss 0.02556, Val sim-NRMS 0.05396, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  134, sqrt loss 0.02438, Val sim-NRMS 0.06753, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  135, sqrt loss  0.0237, Val sim-NRMS 0.06179, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  136, sqrt loss   0.023, Val sim-NRMS 0.06315, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  137, sqrt loss 0.02349, Val sim-NRMS 0.05643, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  138, sqrt loss 0.02364, Val sim-NRMS 0.0583, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  139, sqrt loss 0.02525, Val sim-NRMS 0.1088, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  140, sqrt loss 0.02332, Val sim-NRMS 0.05644, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  141, sqrt loss 0.02281, Val sim-NRMS 0.05711, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  142, sqrt loss 0.02506, Val sim-NRMS 0.05921, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  143, sqrt loss 0.02305, Val sim-NRMS 0.1561, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  144, sqrt loss 0.08426, Val sim-NRMS 0.5733, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  145, sqrt loss  0.7051, Val sim-NRMS 0.7463, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  146, sqrt loss  0.6927, Val sim-NRMS 0.7288, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  147, sqrt loss  0.6586, Val sim-NRMS 0.7129, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  148, sqrt loss  0.3287, Val sim-NRMS 0.3004, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  149, sqrt loss 0.07335, Val sim-NRMS 0.1525, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  150, sqrt loss 0.04277, Val sim-NRMS 0.09778, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  151, sqrt loss 0.03601, Val sim-NRMS 0.1139, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  152, sqrt loss 0.03256, Val sim-NRMS 0.1039, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  153, sqrt loss 0.03172, Val sim-NRMS 0.2237, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  154, sqrt loss 0.09236, Val sim-NRMS 0.1344, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  155, sqrt loss 0.04174, Val sim-NRMS 0.09284, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  156, sqrt loss  0.0275, Val sim-NRMS 0.07519, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  157, sqrt loss 0.02486, Val sim-NRMS 0.05461, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  158, sqrt loss 0.02578, Val sim-NRMS 0.0647, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  159, sqrt loss 0.02634, Val sim-NRMS 0.06051, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  160, sqrt loss 0.02715, Val sim-NRMS 0.1104, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  161, sqrt loss 0.02324, Val sim-NRMS 0.08046, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  162, sqrt loss 0.02409, Val sim-NRMS 0.06269, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  163, sqrt loss 0.02501, Val sim-NRMS 0.08378, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  164, sqrt loss  0.2886, Val sim-NRMS 0.7486, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  165, sqrt loss   0.692, Val sim-NRMS 0.7212, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  166, sqrt loss  0.4034, Val sim-NRMS 0.3965, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  167, sqrt loss 0.08894, Val sim-NRMS  0.175, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  168, sqrt loss 0.04774, Val sim-NRMS 0.1036, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  169, sqrt loss  0.0361, Val sim-NRMS 0.09819, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  170, sqrt loss 0.03439, Val sim-NRMS 0.1214, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  171, sqrt loss 0.02932, Val sim-NRMS 0.08214, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  172, sqrt loss  0.0273, Val sim-NRMS 0.06523, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  173, sqrt loss 0.02652, Val sim-NRMS 0.08154, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.051443415135321455
# Epoch  174, sqrt loss 0.02494, Val sim-NRMS 0.05144, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  175, sqrt loss  0.0258, Val sim-NRMS 0.09571, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  176, sqrt loss 0.02509, Val sim-NRMS 0.0572, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  177, sqrt loss 0.02445, Val sim-NRMS 0.0682, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  178, sqrt loss 0.02503, Val sim-NRMS 0.09892, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.0495412769191401
# Epoch  179, sqrt loss 0.02642, Val sim-NRMS 0.04954, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  180, sqrt loss 0.02355, Val sim-NRMS 0.07988, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  181, sqrt loss 0.02221, Val sim-NRMS 0.05079, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  182, sqrt loss 0.02465, Val sim-NRMS 0.1057, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  183, sqrt loss 0.02559, Val sim-NRMS 0.06951, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.04919213346638248
# Epoch  184, sqrt loss 0.02235, Val sim-NRMS 0.04919, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  185, sqrt loss 0.02226, Val sim-NRMS 0.0566, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  186, sqrt loss 0.02408, Val sim-NRMS 0.09798, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  187, sqrt loss  0.0232, Val sim-NRMS 0.05556, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  188, sqrt loss 0.02119, Val sim-NRMS 0.06204, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  189, sqrt loss  0.2441, Val sim-NRMS  0.625, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  190, sqrt loss  0.3284, Val sim-NRMS 0.2264, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  191, sqrt loss 0.07809, Val sim-NRMS 0.1269, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  192, sqrt loss 0.04106, Val sim-NRMS 0.1021, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  193, sqrt loss 0.03112, Val sim-NRMS 0.06998, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  194, sqrt loss  0.0264, Val sim-NRMS 0.0766, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  195, sqrt loss 0.02396, Val sim-NRMS 0.05457, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  196, sqrt loss 0.02429, Val sim-NRMS 0.08646, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.047906800138177205
# Epoch  197, sqrt loss 0.02175, Val sim-NRMS 0.04791, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  198, sqrt loss 0.02087, Val sim-NRMS 0.07241, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  199, sqrt loss 0.02062, Val sim-NRMS 0.05582, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  200, sqrt loss 0.02067, Val sim-NRMS 0.05096, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  201, sqrt loss 0.01986, Val sim-NRMS 0.04876, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  202, sqrt loss 0.02021, Val sim-NRMS 0.06603, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  203, sqrt loss 0.01989, Val sim-NRMS 0.09501, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.04593489058540122
# Epoch  204, sqrt loss 0.02046, Val sim-NRMS 0.04593, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  205, sqrt loss 0.02118, Val sim-NRMS 0.05307, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.041455387241400875
# Epoch  206, sqrt loss 0.01967, Val sim-NRMS 0.04146, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  207, sqrt loss 0.01849, Val sim-NRMS 0.04993, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  208, sqrt loss 0.01901, Val sim-NRMS 0.06293, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  209, sqrt loss 0.02181, Val sim-NRMS 0.08186, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  210, sqrt loss 0.02041, Val sim-NRMS 0.04497, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  211, sqrt loss 0.02033, Val sim-NRMS 0.05111, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  212, sqrt loss 0.01965, Val sim-NRMS 0.06159, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  213, sqrt loss 0.02104, Val sim-NRMS 0.05006, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  214, sqrt loss  0.0197, Val sim-NRMS 0.05061, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  215, sqrt loss 0.02201, Val sim-NRMS 0.04199, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  216, sqrt loss  0.0221, Val sim-NRMS 0.09135, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  217, sqrt loss 0.02365, Val sim-NRMS 0.05895, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  218, sqrt loss 0.02188, Val sim-NRMS 0.04857, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  219, sqrt loss 0.01813, Val sim-NRMS 0.1052, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  220, sqrt loss 0.02016, Val sim-NRMS 0.08638, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  221, sqrt loss 0.02546, Val sim-NRMS 0.3369, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  222, sqrt loss 0.03223, Val sim-NRMS 0.6417, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  223, sqrt loss 0.04882, Val sim-NRMS 0.1212, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  224, sqrt loss 0.02691, Val sim-NRMS 0.2171, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  225, sqrt loss 0.03772, Val sim-NRMS 0.2339, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  226, sqrt loss  0.4614, Val sim-NRMS 0.7284, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  227, sqrt loss  0.3975, Val sim-NRMS 0.2868, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  228, sqrt loss 0.07349, Val sim-NRMS 0.0954, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  229, sqrt loss 0.03355, Val sim-NRMS 0.06886, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  230, sqrt loss 0.02591, Val sim-NRMS 0.06983, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  231, sqrt loss 0.02446, Val sim-NRMS 0.05558, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  232, sqrt loss 0.02366, Val sim-NRMS 0.0813, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  233, sqrt loss 0.02491, Val sim-NRMS 0.1122, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  234, sqrt loss 0.02241, Val sim-NRMS 0.04794, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  235, sqrt loss  0.0231, Val sim-NRMS 0.1704, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# 60 Epoch  236, sqrt loss  0.4274, Val sim-NRMS 0.6676, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  237, sqrt loss  0.2221, Val sim-NRMS 0.2193, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  238, sqrt loss 0.07376, Val sim-NRMS 0.2018, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  239, sqrt loss 0.04561, Val sim-NRMS 0.08969, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  240, sqrt loss 0.03148, Val sim-NRMS 0.08334, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  241, sqrt loss 0.02817, Val sim-NRMS 0.08341, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  242, sqrt loss 0.02476, Val sim-NRMS 0.0628, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  243, sqrt loss 0.02302, Val sim-NRMS 0.07266, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  244, sqrt loss 0.02326, Val sim-NRMS 0.04834, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  245, sqrt loss 0.02316, Val sim-NRMS 0.09313, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  246, sqrt loss  0.0236, Val sim-NRMS 0.06699, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  247, sqrt loss 0.02215, Val sim-NRMS 0.05512, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  248, sqrt loss 0.02122, Val sim-NRMS 0.06051, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  249, sqrt loss 0.02008, Val sim-NRMS 0.0468, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  250, sqrt loss    0.02, Val sim-NRMS 0.04583, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  251, sqrt loss 0.02042, Val sim-NRMS 0.04812, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  252, sqrt loss 0.02157, Val sim-NRMS 0.08315, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  253, sqrt loss 0.01953, Val sim-NRMS 0.08022, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  254, sqrt loss 0.02125, Val sim-NRMS 0.05898, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  255, sqrt loss 0.01823, Val sim-NRMS 0.04729, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  256, sqrt loss 0.01878, Val sim-NRMS 0.07555, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  257, sqrt loss 0.02213, Val sim-NRMS 0.07583, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  258, sqrt loss 0.02034, Val sim-NRMS 0.05905, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  259, sqrt loss 0.01906, Val sim-NRMS  0.121, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  260, sqrt loss 0.02573, Val sim-NRMS 0.1453, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  261, sqrt loss 0.02691, Val sim-NRMS 0.1079, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  262, sqrt loss  0.0196, Val sim-NRMS 0.0571, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  263, sqrt loss 0.02663, Val sim-NRMS 0.1345, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  264, sqrt loss  0.0254, Val sim-NRMS 0.1798, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  265, sqrt loss  0.0217, Val sim-NRMS 0.09353, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  266, sqrt loss 0.01931, Val sim-NRMS 0.06577, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  267, sqrt loss 0.01865, Val sim-NRMS 0.05384, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  268, sqrt loss 0.01871, Val sim-NRMS 0.0475, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  269, sqrt loss 0.02328, Val sim-NRMS 0.0912, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  270, sqrt loss 0.03907, Val sim-NRMS  0.199, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  271, sqrt loss  0.4722, Val sim-NRMS 0.8999, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  272, sqrt loss  0.1999, Val sim-NRMS 0.2343, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  273, sqrt loss 0.05439, Val sim-NRMS 0.1233, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  274, sqrt loss 0.03373, Val sim-NRMS 0.1171, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  275, sqrt loss 0.02665, Val sim-NRMS 0.09024, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  276, sqrt loss 0.02263, Val sim-NRMS 0.05139, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  277, sqrt loss  0.0201, Val sim-NRMS 0.04752, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  278, sqrt loss 0.02054, Val sim-NRMS 0.0444, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  279, sqrt loss 0.01973, Val sim-NRMS 0.05827, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.04053311951117764
# Epoch  280, sqrt loss 0.01888, Val sim-NRMS 0.04053, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  281, sqrt loss 0.01834, Val sim-NRMS 0.04343, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  282, sqrt loss  0.0198, Val sim-NRMS 0.09625, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  283, sqrt loss  0.0194, Val sim-NRMS 0.04101, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  284, sqrt loss 0.01832, Val sim-NRMS  0.041, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  285, sqrt loss 0.01766, Val sim-NRMS 0.0442, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.03722312333719851
# Epoch  286, sqrt loss 0.02057, Val sim-NRMS 0.03722, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  287, sqrt loss 0.01805, Val sim-NRMS 0.0821, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  288, sqrt loss 0.02087, Val sim-NRMS 0.08372, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  289, sqrt loss 0.02781, Val sim-NRMS 0.05294, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  290, sqrt loss 0.02039, Val sim-NRMS 0.0387, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  291, sqrt loss  0.0185, Val sim-NRMS 0.05895, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  292, sqrt loss 0.02066, Val sim-NRMS 0.08837, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  293, sqrt loss 0.02645, Val sim-NRMS 0.1899, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  294, sqrt loss 0.03178, Val sim-NRMS 0.09715, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  295, sqrt loss 0.03057, Val sim-NRMS 0.07248, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  296, sqrt loss 0.02112, Val sim-NRMS 0.03971, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  297, sqrt loss 0.03043, Val sim-NRMS 0.1015, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  298, sqrt loss 0.02227, Val sim-NRMS 0.1239, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  299, sqrt loss 0.03233, Val sim-NRMS 0.09246, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  300, sqrt loss 0.02609, Val sim-NRMS 0.05148, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  301, sqrt loss 0.02666, Val sim-NRMS 0.1268, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# 69 Epoch  302, sqrt loss  0.3721, Val sim-NRMS 0.7612, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  303, sqrt loss  0.7264, Val sim-NRMS 0.7388, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  304, sqrt loss  0.6794, Val sim-NRMS 0.7253, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  305, sqrt loss   0.524, Val sim-NRMS 0.5996, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  306, sqrt loss  0.1492, Val sim-NRMS 0.2042, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  307, sqrt loss 0.06984, Val sim-NRMS 0.1766, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  308, sqrt loss   0.392, Val sim-NRMS 0.6622, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  309, sqrt loss  0.2963, Val sim-NRMS 0.2955, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  310, sqrt loss 0.07842, Val sim-NRMS 0.1593, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  311, sqrt loss 0.05168, Val sim-NRMS 0.1119, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  312, sqrt loss 0.04373, Val sim-NRMS 0.0998, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  313, sqrt loss 0.03664, Val sim-NRMS 0.1224, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  314, sqrt loss 0.03305, Val sim-NRMS 0.07627, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  315, sqrt loss 0.03068, Val sim-NRMS 0.07285, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  316, sqrt loss 0.02973, Val sim-NRMS 0.09973, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  317, sqrt loss 0.02684, Val sim-NRMS 0.06336, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  318, sqrt loss 0.02538, Val sim-NRMS 0.04833, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  319, sqrt loss 0.02507, Val sim-NRMS 0.06528, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  320, sqrt loss 0.02471, Val sim-NRMS 0.04971, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  321, sqrt loss 0.02391, Val sim-NRMS 0.04869, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  322, sqrt loss 0.02677, Val sim-NRMS 0.06474, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  323, sqrt loss  0.0225, Val sim-NRMS 0.07092, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  324, sqrt loss 0.02282, Val sim-NRMS 0.09327, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  325, sqrt loss  0.0226, Val sim-NRMS 0.04797, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  326, sqrt loss 0.02563, Val sim-NRMS 0.08232, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  327, sqrt loss 0.03778, Val sim-NRMS 0.3231, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# 60 Epoch  328, sqrt loss   0.593, Val sim-NRMS  0.733, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  329, sqrt loss  0.4649, Val sim-NRMS 0.3303, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  330, sqrt loss 0.09045, Val sim-NRMS 0.1211, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  331, sqrt loss 0.04177, Val sim-NRMS 0.1088, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  332, sqrt loss 0.03187, Val sim-NRMS 0.07973, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  333, sqrt loss 0.02748, Val sim-NRMS 0.05562, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  334, sqrt loss 0.02378, Val sim-NRMS 0.04855, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  335, sqrt loss 0.02218, Val sim-NRMS 0.05846, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  336, sqrt loss 0.02134, Val sim-NRMS 0.05683, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  337, sqrt loss 0.02113, Val sim-NRMS 0.03999, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  338, sqrt loss 0.02029, Val sim-NRMS 0.04245, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  339, sqrt loss 0.02093, Val sim-NRMS 0.1065, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  340, sqrt loss 0.02051, Val sim-NRMS 0.04461, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  341, sqrt loss 0.01927, Val sim-NRMS 0.04929, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  342, sqrt loss 0.01921, Val sim-NRMS 0.08373, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  343, sqrt loss 0.01912, Val sim-NRMS 0.07253, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  344, sqrt loss 0.01884, Val sim-NRMS 0.04163, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  345, sqrt loss 0.01815, Val sim-NRMS 0.04119, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  346, sqrt loss 0.01912, Val sim-NRMS 0.08253, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  347, sqrt loss  0.0189, Val sim-NRMS 0.06247, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  348, sqrt loss 0.01792, Val sim-NRMS 0.04799, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  349, sqrt loss 0.01764, Val sim-NRMS 0.05974, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  350, sqrt loss 0.01819, Val sim-NRMS 0.04976, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  351, sqrt loss 0.01933, Val sim-NRMS 0.08617, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  352, sqrt loss 0.01825, Val sim-NRMS 0.03844, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  353, sqrt loss 0.01683, Val sim-NRMS 0.04601, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  354, sqrt loss 0.01723, Val sim-NRMS 0.06701, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  355, sqrt loss 0.01773, Val sim-NRMS 0.0474, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  356, sqrt loss 0.01765, Val sim-NRMS 0.04118, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  357, sqrt loss 0.01842, Val sim-NRMS 0.06129, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  358, sqrt loss 0.02154, Val sim-NRMS 0.08564, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  359, sqrt loss 0.01788, Val sim-NRMS 0.06763, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  360, sqrt loss 0.01693, Val sim-NRMS 0.05007, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  361, sqrt loss 0.01916, Val sim-NRMS 0.08896, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  362, sqrt loss  0.0261, Val sim-NRMS 0.05871, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  363, sqrt loss 0.01992, Val sim-NRMS 0.04634, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  364, sqrt loss  0.0265, Val sim-NRMS 0.1255, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  365, sqrt loss 0.02285, Val sim-NRMS 0.0506, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  366, sqrt loss 0.02736, Val sim-NRMS   0.27, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# 54 Epoch  367, sqrt loss  0.5983, Val sim-NRMS 0.7127, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  368, sqrt loss  0.3348, Val sim-NRMS 0.3007, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  369, sqrt loss 0.07556, Val sim-NRMS 0.1069, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  370, sqrt loss 0.03711, Val sim-NRMS 0.1067, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  371, sqrt loss 0.02938, Val sim-NRMS 0.07515, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  372, sqrt loss 0.02372, Val sim-NRMS 0.05364, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  373, sqrt loss 0.02098, Val sim-NRMS 0.0543, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  374, sqrt loss  0.0206, Val sim-NRMS 0.04427, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  375, sqrt loss 0.01827, Val sim-NRMS 0.05263, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  376, sqrt loss 0.01779, Val sim-NRMS 0.03733, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  377, sqrt loss 0.01825, Val sim-NRMS 0.04583, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  378, sqrt loss 0.01743, Val sim-NRMS 0.04401, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  379, sqrt loss 0.01701, Val sim-NRMS 0.06844, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  380, sqrt loss 0.01829, Val sim-NRMS 0.1274, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  381, sqrt loss 0.01792, Val sim-NRMS 0.04533, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  382, sqrt loss 0.01701, Val sim-NRMS 0.06297, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  383, sqrt loss 0.01747, Val sim-NRMS 0.04886, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.02954599477404352
# Epoch  384, sqrt loss  0.0179, Val sim-NRMS 0.02955, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  385, sqrt loss 0.01575, Val sim-NRMS 0.03652, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  386, sqrt loss 0.01826, Val sim-NRMS 0.03135, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  387, sqrt loss 0.01564, Val sim-NRMS 0.03641, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  388, sqrt loss 0.01732, Val sim-NRMS 0.06515, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  389, sqrt loss 0.01548, Val sim-NRMS 0.0721, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  390, sqrt loss 0.01771, Val sim-NRMS 0.03482, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  391, sqrt loss 0.01636, Val sim-NRMS 0.05892, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  392, sqrt loss 0.01731, Val sim-NRMS 0.05184, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  393, sqrt loss 0.02064, Val sim-NRMS 0.3494, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ...
# Epoch  441, sqrt loss 0.02825, Val sim-NRMS 0.2126, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# 55 71 Epoch  442, sqrt loss  0.4589, Val sim-NRMS 0.7385, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  443, sqrt loss  0.4239, Val sim-NRMS 0.3019, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  444, sqrt loss 0.08738, Val sim-NRMS 0.1481, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  445, sqrt loss   0.046, Val sim-NRMS 0.1105, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  446, sqrt loss 0.03563, Val sim-NRMS 0.08939, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  447, sqrt loss 0.03056, Val sim-NRMS 0.1084, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  448, sqrt loss 0.02788, Val sim-NRMS 0.07852, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  449, sqrt loss 0.02614, Val sim-NRMS 0.09028, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  450, sqrt loss 0.02496, Val sim-NRMS 0.06329, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  451, sqrt loss 0.02397, Val sim-NRMS 0.06096, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  452, sqrt loss 0.02234, Val sim-NRMS 0.0659, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  453, sqrt loss 0.02206, Val sim-NRMS 0.07743, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  454, sqrt loss 0.02095, Val sim-NRMS 0.04949, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  455, sqrt loss 0.02061, Val sim-NRMS 0.06408, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  456, sqrt loss 0.01987, Val sim-NRMS 0.0554, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  457, sqrt loss 0.02074, Val sim-NRMS 0.06256, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  458, sqrt loss 0.01922, Val sim-NRMS 0.03975, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  459, sqrt loss 0.01908, Val sim-NRMS 0.04077, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  460, sqrt loss 0.01784, Val sim-NRMS 0.05482, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  461, sqrt loss 0.01858, Val sim-NRMS 0.04851, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  462, sqrt loss 0.01831, Val sim-NRMS 0.07809, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  463, sqrt loss  0.0188, Val sim-NRMS 0.06012, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  464, sqrt loss 0.01834, Val sim-NRMS 0.06442, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  465, sqrt loss 0.01707, Val sim-NRMS 0.0359, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  466, sqrt loss 0.01701, Val sim-NRMS 0.06377, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  467, sqrt loss 0.01754, Val sim-NRMS 0.03949, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  468, sqrt loss 0.01584, Val sim-NRMS 0.04869, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  469, sqrt loss 0.01693, Val sim-NRMS 0.04004, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  470, sqrt loss 0.01617, Val sim-NRMS 0.03005, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  471, sqrt loss 0.01617, Val sim-NRMS 0.03731, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  472, sqrt loss 0.01675, Val sim-NRMS 0.03412, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  473, sqrt loss 0.01646, Val sim-NRMS 0.0336, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  474, sqrt loss 0.01853, Val sim-NRMS 0.06991, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  475, sqrt loss 0.01718, Val sim-NRMS 0.06674, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  476, sqrt loss 0.01574, Val sim-NRMS 0.04611, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  477, sqrt loss 0.01883, Val sim-NRMS 0.05439, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  478, sqrt loss 0.01898, Val sim-NRMS 0.07916, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  479, sqrt loss 0.01801, Val sim-NRMS 0.05791, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  480, sqrt loss 0.02077, Val sim-NRMS 0.03579, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  481, sqrt loss 0.01694, Val sim-NRMS 0.06412, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  482, sqrt loss  0.0207, Val sim-NRMS 0.05634, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  483, sqrt loss 0.02141, Val sim-NRMS 0.07598, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  484, sqrt loss 0.02362, Val sim-NRMS 0.03958, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  485, sqrt loss 0.01915, Val sim-NRMS 0.04849, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  486, sqrt loss  0.0181, Val sim-NRMS 0.05889, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  487, sqrt loss 0.02817, Val sim-NRMS 0.09044, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  488, sqrt loss 0.02761, Val sim-NRMS  0.039, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  489, sqrt loss 0.01773, Val sim-NRMS 0.06309, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  490, sqrt loss 0.02094, Val sim-NRMS 0.1133, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  491, sqrt loss  0.0321, Val sim-NRMS 0.2966, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  492, sqrt loss 0.02264, Val sim-NRMS  0.089, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  493, sqrt loss 0.04186, Val sim-NRMS 0.1626, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.029444404814509738
# Epoch  494, sqrt loss 0.02316, Val sim-NRMS 0.02944, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  495, sqrt loss 0.02486, Val sim-NRMS 0.0644, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  496, sqrt loss 0.02887, Val sim-NRMS 0.08012, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  497, sqrt loss 0.02201, Val sim-NRMS 0.07532, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  498, sqrt loss 0.01796, Val sim-NRMS 0.07728, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  499, sqrt loss 0.01685, Val sim-NRMS 0.1814, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  500, sqrt loss  0.2728, Val sim-NRMS 0.7639, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  501, sqrt loss  0.7279, Val sim-NRMS 0.7456, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  502, sqrt loss  0.6875, Val sim-NRMS 0.7263, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  503, sqrt loss  0.6565, Val sim-NRMS 0.7532, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  504, sqrt loss  0.6982, Val sim-NRMS 0.7279, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  505, sqrt loss   0.525, Val sim-NRMS 0.5669, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  506, sqrt loss  0.1236, Val sim-NRMS 0.2339, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  507, sqrt loss 0.06808, Val sim-NRMS 0.1653, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  508, sqrt loss 0.05061, Val sim-NRMS 0.1237, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  509, sqrt loss 0.04463, Val sim-NRMS 0.1141, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  510, sqrt loss 0.04036, Val sim-NRMS 0.1159, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  511, sqrt loss 0.03913, Val sim-NRMS 0.1703, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  512, sqrt loss  0.5108, Val sim-NRMS 0.7405, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  513, sqrt loss  0.6878, Val sim-NRMS 0.7271, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  514, sqrt loss  0.6156, Val sim-NRMS 0.6342, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  515, sqrt loss  0.1894, Val sim-NRMS 0.2791, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  516, sqrt loss 0.05593, Val sim-NRMS 0.1956, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  517, sqrt loss 0.03987, Val sim-NRMS 0.1168, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  518, sqrt loss 0.03678, Val sim-NRMS 0.1169, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  519, sqrt loss 0.03604, Val sim-NRMS 0.1405, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  520, sqrt loss 0.03318, Val sim-NRMS 0.08906, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  521, sqrt loss 0.03027, Val sim-NRMS 0.08947, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  522, sqrt loss 0.02892, Val sim-NRMS 0.1064, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  523, sqrt loss 0.02884, Val sim-NRMS 0.1228, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  524, sqrt loss 0.02883, Val sim-NRMS 0.07824, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  525, sqrt loss 0.02645, Val sim-NRMS 0.08059, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  526, sqrt loss  0.0247, Val sim-NRMS  0.076, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  527, sqrt loss 0.02443, Val sim-NRMS 0.07119, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  528, sqrt loss 0.02437, Val sim-NRMS 0.08662, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  529, sqrt loss 0.02588, Val sim-NRMS 0.09635, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  530, sqrt loss 0.02358, Val sim-NRMS 0.07081, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  531, sqrt loss 0.02358, Val sim-NRMS 0.07413, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  532, sqrt loss 0.02335, Val sim-NRMS 0.05977, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  533, sqrt loss 0.02183, Val sim-NRMS 0.08188, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  534, sqrt loss 0.02095, Val sim-NRMS 0.08829, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  535, sqrt loss 0.02206, Val sim-NRMS 0.06666, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  536, sqrt loss  0.0212, Val sim-NRMS 0.08876, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  537, sqrt loss 0.02762, Val sim-NRMS 0.1825, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  538, sqrt loss 0.08132, Val sim-NRMS 0.6139, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  539, sqrt loss  0.2754, Val sim-NRMS 0.2463, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  540, sqrt loss 0.05977, Val sim-NRMS  0.123, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  541, sqrt loss 0.03089, Val sim-NRMS 0.08016, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  542, sqrt loss 0.02492, Val sim-NRMS 0.08593, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  543, sqrt loss 0.02351, Val sim-NRMS 0.09326, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  544, sqrt loss 0.02322, Val sim-NRMS 0.06746, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  545, sqrt loss 0.02225, Val sim-NRMS 0.08066, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  546, sqrt loss 0.02315, Val sim-NRMS 0.1117, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  547, sqrt loss 0.02222, Val sim-NRMS 0.05735, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  548, sqrt loss 0.02231, Val sim-NRMS 0.06111, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  549, sqrt loss 0.02113, Val sim-NRMS 0.06224, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  550, sqrt loss 0.02112, Val sim-NRMS 0.1056, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  551, sqrt loss 0.02066, Val sim-NRMS 0.0968, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  552, sqrt loss 0.02016, Val sim-NRMS 0.1234, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  553, sqrt loss 0.02061, Val sim-NRMS 0.06274, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  554, sqrt loss 0.01966, Val sim-NRMS 0.05359, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  555, sqrt loss 0.01998, Val sim-NRMS 0.05254, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  556, sqrt loss 0.01959, Val sim-NRMS 0.06443, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  557, sqrt loss 0.02081, Val sim-NRMS 0.07932, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  558, sqrt loss 0.02117, Val sim-NRMS 0.04948, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  559, sqrt loss 0.02008, Val sim-NRMS 0.07181, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  560, sqrt loss 0.01919, Val sim-NRMS 0.05017, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  561, sqrt loss 0.01858, Val sim-NRMS 0.05815, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  562, sqrt loss 0.01913, Val sim-NRMS 0.04029, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  563, sqrt loss 0.01988, Val sim-NRMS 0.04546, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  564, sqrt loss 0.01977, Val sim-NRMS 0.08837, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  565, sqrt loss 0.02231, Val sim-NRMS 0.1057, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  566, sqrt loss 0.01998, Val sim-NRMS 0.0523, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  567, sqrt loss 0.01774, Val sim-NRMS 0.0601, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  568, sqrt loss 0.01895, Val sim-NRMS 0.05677, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  569, sqrt loss 0.02887, Val sim-NRMS 0.1583, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  570, sqrt loss 0.02632, Val sim-NRMS 0.1403, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  571, sqrt loss 0.02259, Val sim-NRMS 0.1057, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  572, sqrt loss 0.04052, Val sim-NRMS 0.4227, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  573, sqrt loss  0.5771, Val sim-NRMS  0.719, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  574, sqrt loss  0.4692, Val sim-NRMS 0.6882, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  575, sqrt loss  0.2535, Val sim-NRMS 0.2504, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  576, sqrt loss 0.05721, Val sim-NRMS 0.0936, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  577, sqrt loss 0.03516, Val sim-NRMS 0.1003, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  578, sqrt loss 0.03016, Val sim-NRMS 0.0904, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  579, sqrt loss 0.02729, Val sim-NRMS 0.06665, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  580, sqrt loss 0.02554, Val sim-NRMS 0.08357, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Epoch  581, sqrt loss 0.02413, Val sim-NRMS 0.05448, Time Loss: 60.0%, data: 0.1%, val: 39.9%,  1.5 batches/sec
# Stopping early due to a KeyboardInterrupt
# Loaded model with best known validation sim-NRMS of 0.02944 which happened on epoch 494 (epoch_id=568.00)

# %%
#sys.save_system('results/gyroscope_nx5_np3_na10_nb10')

# %%
sys = deepSI.load_system('results/gyroscope_nx5_np3_na10_nb10')

# %%
res1 = sys.apply_experiment(train)
print("Training RMS: " + str(res1.RMS(train)))
print("Training NRMS: " + str(res1.NRMS(train) * 100) + "%")

res2 = sys.apply_experiment(test)
print("Test RMS: " + str(res2.RMS(test)))
print("Test NRMS: " + str(res2.NRMS(test) * 100) + "%")
print("Test BFR: " + str((1 - res2.NRMS(test)) * 100) + "%")

plt.plot(train.y)
plt.plot(res1.y - train.y)
plt.show()
plt.plot(test.y)
plt.plot(res2.y - test.y)
plt.show()
# Out:
# /home/frank/.local/lib/python3.9/site-packages/deepSI/fit_systems/encoders.py:230: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:230.)
#   action = torch.tensor(action, dtype=torch.float32) #(N,...)
# Training RMS: 0.009115275757672896
# Training NRMS: 3.5786876298775034%
# Test RMS: 0.01670750815448194
# Test NRMS: 6.459899072528613%
# Test BFR: 93.54010092747139%
